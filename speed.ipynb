# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format ='svg'

# %%
# PerispBunker07
# gamma=4.5，vel=0.5，angV=15
sp07=[]
sp07sum=463
sp07move=0
Flag=True
for i in range(0,sp07sum+1):
    data = pd.read_csv(r'/home/zhi/Documents/Data/PerispBunker07/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        sp07.append([x,y,z,v])
        if Flag:
            sp07move=i
            Flag=False
    else:
        sp07.append([0,0,0,0])
        
# PerispBunker06
# gamma=4.5，vel=0.5，angV=10(即与screw19参数相同)
sp06=[]
sp06sum=511
sp06move=0
Flag=True
for i in range(0,sp06sum+1):
    data = pd.read_csv(r'/home/zhi/Documents/Data/PerispBunker06/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        sp06.append([x,y,z,v])
        if Flag:
            sp06move=i
            Flag=False
    else:
        sp06.append([0,0,0,0])
        
# PerispBunker08
# gamma=4.5，vel=0.5，angV=5(即与screw19参数相同)
sp08=[]
sp08sum=646
sp08move=0
Flag=True
for i in range(0,sp08sum+1):
    data = pd.read_csv(r'/home/zhi/Documents/Data/PerispBunker08/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        sp08.append([x,y,z,v])
        if Flag:
            sp08move=i
            Flag=False
    else:
        sp08.append([0,0,0,0])

# %%
plt.plot([i for i in range(0,sp08sum+1-sp08move)], [j[0] for j in sp08[sp08move:]],label='$angV5-Vel_X$')
plt.plot([i for i in range(0,sp08sum+1-sp08move)], [j[1] for j in sp08[sp08move:]],label='$angV5-Vel_Y$')
plt.plot([i for i in range(0,sp08sum+1-sp08move)], [j[2] for j in sp08[sp08move:]],label='$angV5-Vel_Z$')
# plt.plot([i for i in range(0,sp08sum+1-sp08move)], [j[3] for j in sp08[sp08move:]],label='$angV5-Vel_V$')

plt.plot([i for i in range(0,sp06sum+1-sp06move)], [j[0] for j in sp06[sp06move:]],label='$angV10-Vel_X$')
plt.plot([i for i in range(0,sp06sum+1-sp06move)], [j[1] for j in sp06[sp06move:]],label='$angV10-Vel_Y$')
plt.plot([i for i in range(0,sp06sum+1-sp06move)], [j[2] for j in sp06[sp06move:]],label='$angV10-Vel_Z$')
# plt.plot([i for i in range(0,sp06sum+1-sp06move)], [j[3] for j in sp06[sp06move:]],label='$angV10-Vel_V$')

plt.plot([i for i in range(0,sp07sum+1-sp07move)], [j[0] for j in sp07[sp07move:]],label='$angV15-Vel_X$')
plt.plot([i for i in range(0,sp07sum+1-sp07move)], [j[1] for j in sp07[sp07move:]],label='$angV15-Vel_Y$')
plt.plot([i for i in range(0,sp07sum+1-sp07move)], [j[2] for j in sp07[sp07move:]],label='$angV15-Vel_Z$')
# plt.plot([i for i in range(0,sp07sum+1-sp07move)], [j[3] for j in sp07[sp07move:]],label='$angV15-Vel_V$')

n=150
avgsp06=np.mean([j[2] for j in sp06[sp06move+n:]])
avgsp07=np.mean([j[2] for j in sp07[sp07move+n:]])
avgsp08=np.mean([j[2] for j in sp08[sp08move+n:]])

plt.plot([i for i in range(n,sp07sum+1-sp07move)], [avgsp07 for i in range(n,sp07sum+1-sp07move)],label='$angV15-Vel_Z$')
plt.plot([i for i in range(n,sp06sum+1-sp06move)], [avgsp06 for i in range(n,sp06sum+1-sp06move)],label='$angV15-Vel_Z$')
plt.plot([i for i in range(n,sp08sum+1-sp08move)], [avgsp08 for i in range(n,sp08sum+1-sp08move)],label='$angV15-Vel_Z$')

plt.xlim(xmin = 0);plt.xlim(xmax = 350)
plt.ylim(ymin = -0.6);plt.ylim(ymax = 0.6)
plt.xlabel('iter')
plt.ylabel('vel')
# plt.legend()
plt.show()

# %%
# Perisp-TestSpeed01
# gamma=4.5，vel=0.5，angV=5
testspeed01=[]
sumdata01=562
moveiter01=0
Flag=True
for i in range(0,sumdata01+1):
    data = pd.read_csv(r'/media/zhi/Data/YADE/Pesp-Speed/speed01/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        testspeed01.append([x,y,z,v])
        if Flag:
            moveiter01=i
            Flag=False
    else:
        testspeed01.append([0,0,0,0])

# Perisp-TestSpeed02
# gamma=4.5，vel=0.5，angV=15
testspeed02=[]
sumdata02=359
moveiter02=0
Flag=True
for i in range(0,sumdata02+1):
    data = pd.read_csv(r'/media/zhi/Data/YADE/Pesp-Speed/speed02/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        testspeed02.append([x,y,z,v])
        if Flag:
            moveiter02=i
            Flag=False
    else:
        testspeed02.append([0,0,0,0])

# Perisp-TestSpeed03
# gamma=4.5，vel=0.5，angV=10
testspeed03=[]
sumdata03=417
moveiter03=0
Flag=True
for i in range(0,sumdata03+1):
    data = pd.read_csv(r'/media/zhi/Data/YADE/Pesp-Speed/speed03/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        testspeed03.append([x,y,z,v])
        if Flag:
            moveiter03=i
            Flag=False
    else:
        testspeed03.append([0,0,0,0])
        
# Perisp-TestSpeed02plus
# gamma=4.5，vel=0.5，angV=15
testspeed02pl=[]
sumdata02pl=466
moveiter02pl=0
Flag=True
for i in range(0,sumdata02pl+1):
    data = pd.read_csv(r'/media/zhi/Data/YADE/Pesp-Speed/speed02plus/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        testspeed02pl.append([x,y,z,v])
        if Flag:
            moveiter02pl=i
            Flag=False
    else:
        testspeed02pl.append([0,0,0,0])

# Perisp-TestSpeed03compare
# gamma=4.5，vel=0.5，angV=10
testspeed03cp=[]
sumdata03cp=419
for i in range(0,sumdata03cp+1):
    data = pd.read_csv(r'/media/zhi/Data/YADE/Pesp-Speed/speed03plus/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        testspeed03cp.append([x,y,z,v])
    else:
        testspeed03cp.append([0,0,0,0])

# %%
plt.figure(figsize=(12,8))
moveiter02+=50
moveiter02pl+=50
# plt.plot([i for i in range(0,sumdata01+1-moveiter01)], [j[0] for j in testspeed01[moveiter01:]],label='$angV5-Vel_X$')
# plt.plot([i for i in range(0,sumdata01+1-moveiter01)], [j[1] for j in testspeed01[moveiter01:]],label='$angV5-Vel_Y$')
# plt.plot([i for i in range(0,sumdata01+1-moveiter01)], [j[2] for j in testspeed01[moveiter01:]],label='$angV5-Vel_Z$')
# plt.plot([i for i in range(0,sumdata01+1-moveiter01)], [j[3] for j in testspeed01[moveiter01:]],label='$angV5-Vel_V$')

# plt.plot([i for i in range(0,sumdata03+1-moveiter03)], [j[0] for j in testspeed03[moveiter03:]],label='$angV10-Vel_X$')
# plt.plot([i for i in range(0,sumdata03+1-moveiter03)], [j[1] for j in testspeed03[moveiter03:]],label='$angV10-Vel_Y$')
# plt.plot([i for i in range(0,sumdata03+1-moveiter03)], [j[2] for j in testspeed03[moveiter03:]],label='$angV10-Vel_Z$')
# plt.plot([i for i in range(0,sumdata03+1-moveiter03)], [j[3] for j in testspeed03[moveiter03:]],label='$angV10-Vel_V$')

# plt.plot([i for i in range(0,sumdata02+1-moveiter02)], [j[0] for j in testspeed02[moveiter02:]],label='$angV15-Vel_X$')
# plt.plot([i for i in range(0,sumdata02+1-moveiter02)], [j[1] for j in testspeed02[moveiter02:]],label='$angV15-Vel_Y$')
plt.plot([i for i in range(0,sumdata02+1-moveiter02)], [j[2] for j in testspeed02[moveiter02:]],label='$angV15-Vel_Z$')
# plt.plot([i for i in range(0,sumdata02+1-moveiter02)], [j[3] for j in testspeed02[moveiter02:]],label='$angV15-Vel_V$')

# plt.plot([i for i in range(0,sumdata02pl+1-moveiter02pl)], [j[0] for j in testspeed02pl[moveiter02pl:]],label='$angV15-Vel_X$')
# plt.plot([i for i in range(0,sumdata02pl+1-moveiter02pl)], [j[1] for j in testspeed02pl[moveiter02pl:]],label='$angV15-Vel_Y$')
plt.plot([i for i in range(0,sumdata02pl+1-moveiter02pl)], [j[2] for j in testspeed02pl[moveiter02pl:]],label='$angV15-Vel_Z$')

# plt.plot([i for i in range(0,sumdata03+1)], [j[0] for j in testspeed03],label='Vel-X')
# plt.plot([i for i in range(0,sumdata03+1)], [j[1] for j in testspeed03],label='Vel-Y')
# plt.plot([i for i in range(0,sumdata03+1)], [j[2] for j in testspeed03],label='Vel-Z')
# plt.plot([i for i in range(0,sumdata03+1)], [j[3] for j in testspeed03],label='Vel-V')
# plt.xlim(xmin = 0)
# plt.ylim(ymax = 0)
plt.xlabel('iter')
plt.ylabel('vel')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot([i for i in range(0,sp08sum+1-sp08move)], [j[2] for j in sp08[sp08move:]],label='$Actual angV5-Vel_Z$')
plt.plot([i for i in range(0,sp06sum+1-sp06move)], [j[2] for j in sp06[sp06move:]],label='$Actual angV10-Vel_Z$')
plt.plot([i for i in range(0,sp07sum+1-sp07move)], [j[2] for j in sp07[sp07move:]],label='$Actual angV15-Vel_Z$')

plt.plot([i for i in range(0,sumdata01+1-moveiter01)], [j[2] for j in testspeed01[moveiter01:]],linestyle='-.',label='Test $angV5-Vel_Z$')
plt.plot([i for i in range(0,sumdata03+1-moveiter03)], [j[2] for j in testspeed03[moveiter03:]],linestyle='-.',label='Test $angV10-Vel_Z$')
plt.plot([i for i in range(0,sumdata02+1-moveiter02)], [j[2] for j in testspeed02[moveiter02:]],linestyle='-.',label='Test $angV15-Vel_Z$')

plt.xlabel('iter')
plt.ylabel('vel')
plt.legend()
plt.show()

# %%
# PerispBunker07
# gamma=4.5，vel=0.5，angV=15
sp07no=[]
sp07nosum=461
sp07nomove=0
Flag=True
for i in range(0,sp07nosum+1):
    data = pd.read_csv(r'/media/zhi/Data/YADE/speed07no/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        sp07no.append([x,y,z,v])
        if Flag:
            sp07nomove=i
            Flag=False
    else:
        sp07no.append([0,0,0,0])
        
# PerispBunker06
# gamma=4.5，vel=0.5，angV=10(即与screw19参数相同)
sp06no=[]
sp06nosum=516
sp06nomove=0
Flag=True
for i in range(0,sp06nosum+1):
    data = pd.read_csv(r'/media/zhi/Data/YADE/speed06no/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        sp06no.append([x,y,z,v])
        if Flag:
            sp06nomove=i
            Flag=False
    else:
        sp06no.append([0,0,0,0])
        
# PerispBunker08
# gamma=4.5，vel=0.5，angV=5(即与screw19参数相同)
sp08no=[]
sp08nosum=641
sp08nomove=0
Flag=True
for i in range(0,sp08nosum+1):
    data = pd.read_csv(r'/media/zhi/Data/YADE/speed08no/P_'+str(i)+'.csv', usecols=[0,1,2,3])
    if np.size(data):
        uniques = np.unique(data, axis=0)
        x=np.mean(uniques[:,0],axis=0)
        y=np.mean(uniques[:,1],axis=0)
        z=np.mean(uniques[:,2],axis=0)
        v=np.mean(uniques[:,3],axis=0)
        sp08no.append([x,y,z,v])
        if Flag:
            sp08nomove=i
            Flag=False
    else:
        sp08no.append([0,0,0,0])

# %%
plt.plot([i for i in range(0,sp08nosum+1-sp08nomove)], [j[0] for j in sp08no[sp08nomove:]],label='$angV5-Vel_X$')
plt.plot([i for i in range(0,sp08nosum+1-sp08nomove)], [j[1] for j in sp08no[sp08nomove:]],label='$angV5-Vel_Y$')
plt.plot([i for i in range(0,sp08nosum+1-sp08nomove)], [j[2] for j in sp08no[sp08nomove:]],label='$angV5-Vel_Z$')
# plt.plot([i for i in range(0,sp08nosum+1-sp08nomove)], [j[3] for j in sp08no[sp08nomove:]],label='$angV5-Vel_V$')

plt.plot([i for i in range(0,sp06nosum+1-sp06nomove)], [j[0] for j in sp06no[sp06nomove:]],label='$angV10-Vel_X$')
plt.plot([i for i in range(0,sp06nosum+1-sp06nomove)], [j[1] for j in sp06no[sp06nomove:]],label='$angV10-Vel_Y$')
plt.plot([i for i in range(0,sp06nosum+1-sp06nomove)], [j[2] for j in sp06no[sp06nomove:]],label='$angV10-Vel_Z$')
# plt.plot([i for i in range(0,sp06nosum+1-sp06nomove)], [j[3] for j in sp06no[sp06nomove:]],label='$angV10-Vel_V$')

plt.plot([i for i in range(0,sp07nosum+1-sp07nomove)], [j[0] for j in sp07no[sp07nomove:]],label='$angV15-Vel_X$')
plt.plot([i for i in range(0,sp07nosum+1-sp07nomove)], [j[1] for j in sp07no[sp07nomove:]],label='$angV15-Vel_Y$')
plt.plot([i for i in range(0,sp07nosum+1-sp07nomove)], [j[2] for j in sp07no[sp07nomove:]],label='$angV15-Vel_Z$')
# plt.plot([i for i in range(0,sp07nosum+1-sp07nomove)], [j[3] for j in sp07no[sp07nomove:]],label='$angV15-Vel_V$')

n=150
n=150
avgsp06no=np.mean([j[2] for j in sp06no[sp06nomove+n:]])
avgsp07no=np.mean([j[2] for j in sp07no[sp07nomove+n:]])
avgsp08no=np.mean([j[2] for j in sp08no[sp08nomove+n:]])

plt.plot([i for i in range(n,sp07nosum+1-sp07nomove)], [np.mean([j[2] for j in sp07no[sp07nomove+n:]]) for i in range(n,sp07nosum+1-sp07nomove)],label='$angV15-Vel_Z$')
plt.plot([i for i in range(n,sp06nosum+1-sp06nomove)], [np.mean([j[2] for j in sp06no[sp06nomove+n:]]) for i in range(n,sp06nosum+1-sp06nomove)],label='$angV15-Vel_Z$')
plt.plot([i for i in range(n,sp08nosum+1-sp08nomove)], [np.mean([j[2] for j in sp08no[sp08nomove+n:]]) for i in range(n,sp08nosum+1-sp08nomove)],label='$angV15-Vel_Z$')

plt.xlim(xmin = 0);plt.xlim(xmax = 350)
plt.ylim(ymin = -0.6);plt.ylim(ymax = 0.6)
plt.xlabel('iter')
plt.ylabel('vel')
# plt.legend()
plt.show()

# %%
avgsp06no=np.mean([j[2] for j in testspeed01[moveiter01+n:]])
avgsp07no=np.mean([j[2] for j in testspeed02[moveiter02+n:]])
avgsp08no=np.mean([j[2] for j in testspeed03[moveiter03+n:]])
# Out:
# -0.4194751238665433

# %%
x=[5,10,15];y=[avgsp08,avgsp06,avgsp07]
plt.plot(x,y,marker='x')
for a,b in zip(x,y):
    plt.text(a, b+0.001, '%.4f' % b, ha='center', va= 'bottom',fontsize=9)
yno=[avgsp08no,avgsp06no,avgsp07no]
plt.plot(x,yno,marker='o')
for a,b in zip(x,yno):
    plt.text(a, b+0.001, '%.4f' % b, ha='center', va= 'bottom',fontsize=9)
