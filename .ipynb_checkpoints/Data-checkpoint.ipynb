# %%
import pandas as pd
import re

# %%
data = pd.read_csv('CitationArticles.csv', '\t', index_col=False)

# %%
print(data.columns)
# Out:
# Index(['PT', 'AU', 'BA', 'BE', 'GP', 'AF', 'BF', 'CA', 'TI', 'SO', 'SE', 'BS',
#        'LA', 'DT', 'CT', 'CY', 'CL', 'SP', 'HO', 'DE', 'ID', 'AB', 'C1', 'RP',
#        'EM', 'RI', 'OI', 'FU', 'FX', 'U1', 'U2', 'PU', 'PI', 'PA', 'SN', 'EI',
#        'BN', 'J9', 'JI', 'PD', 'PY', 'VL', 'IS', 'PN', 'SU', 'SI', 'MA', 'BP',
#        'EP', 'AR', 'DI', 'D2', 'EA', 'PG', 'WC', 'SC', 'GA', 'UT', 'PM', 'OA',
#        'HC', 'HP', 'DA'],
#       dtype='object')

# %%
# 统计国家或地区
SumCountries={}
for str in data['C1']:
    countries={}
    if str.count('[')==1:
        c1=str.split(',')[-1].strip()
        if c1[-3:]=='USA':
            c1='USA'
        SumCountries[c1]=SumCountries.get(c1, 0) + 1
    else:
        for i in str.split('; ['):
            c1=i.split(',')[-1].strip()
            if c1[-3:]=='USA':
                c1='USA'
            countries[c1]=countries.get(c1, 0) + 1
        for key in countries.keys():
            SumCountries[key]=SumCountries.get(key, 0) + 1
print('共有国家或地区：', len(SumCountries))
print(sorted(SumCountries.items(), key=lambda item:item[1], reverse=1))
# Out:
# 共有国家或地区： 42
# [('Peoples R China', 34), ('USA', 18), ('Iran', 15), ('India', 8), ('Australia', 6), ('Iraq', 4), ('Germany', 4), ('France', 4), ('U Arab Emirates', 4), ('Brazil', 3), ('Greece', 3), ('South Korea', 3), ('Canada', 3), ('Turkey', 2), ('Spain', 2), ('Pakistan', 2), ('Scotland', 2), ('Portugal', 2), ('Netherlands', 2), ('Vietnam', 2), ('Italy', 2), ('Japan', 2), ('England', 2), ('Poland', 2), ('Thailand', 2), ('Malaysia', 1), ('Algeria', 1), ('Austria', 1), ('Belgium', 1), ('Nigeria', 1), ('New Zealand', 1), ('Brunei', 1), ('Cyprus', 1), ('Colombia', 1), ('Saudi Arabia', 1), ('Croatia', 1), ('Bosnia & Herceg', 1), ('Mexico', 1), ('Russia', 1), ('Ecuador', 1), ('Switzerland', 1), ('Israel', 1)]

# %%
# 来源出版物
SumPublication={}
for Publication in data['SO']:
    SumPublication[Publication]=SumPublication.get(Publication, 0) + 1
for Publication in data['SE']:
    if pd.isnull(Publication)==0:
        SumPublication[Publication]=SumPublication.get(Publication, 0) + 1
print('共有来源出版物：', len(SumPublication))
print(sorted(SumPublication.items(), key=lambda item:item[1], reverse=1))
# Out:
# 共有来源出版物： 77
# [('MATERIALS', 8), ('CONSTRUCTION AND BUILDING MATERIALS', 7), ('FRONTIERS OF STRUCTURAL AND CIVIL ENGINEERING', 7), ('APPLIED SCIENCES-BASEL', 5), ('JOURNAL OF MATERIALS IN CIVIL ENGINEERING', 4), ('SENSORS', 3), ('GEOTECHNICAL AND GEOLOGICAL ENGINEERING', 3), ('INTERNATIONAL JOURNAL OF STRUCTURAL STABILITY AND DYNAMICS', 2), ('ENGINEERING STRUCTURES', 2), ('ROAD MATERIALS AND PAVEMENT DESIGN', 2), ('KSCE JOURNAL OF CIVIL ENGINEERING', 2), ('SUSTAINABILITY', 2), ('FIRST RILEM INTERNATIONAL CONFERENCE ON CONCRETE AND DIGITAL FABRICATION - DIGITAL CONCRETE 2018', 2), ('RILEM Bookseries', 2), ('JOURNAL OF COMPOSITE MATERIALS', 1), ('MATERIALS & DESIGN', 1), ('INTERNATIONAL JOURNAL OF FATIGUE', 1), ('EARTHQUAKE ENGINEERING AND ENGINEERING VIBRATION', 1), ('MATERIALS TESTING', 1), ('THEORETICAL AND APPLIED FRACTURE MECHANICS', 1), ('ARABIAN JOURNAL FOR SCIENCE AND ENGINEERING', 1), ('COMPOSITES PART A-APPLIED SCIENCE AND MANUFACTURING', 1), ('HYDROLOGICAL SCIENCES JOURNAL-JOURNAL DES SCIENCES HYDROLOGIQUES', 1), ('GEOMECHANICS AND GEOENGINEERING-AN INTERNATIONAL JOURNAL', 1), ('EUROPEAN JOURNAL OF WOOD AND WOOD PRODUCTS', 1), ('SURFACE TOPOGRAPHY-METROLOGY AND PROPERTIES', 1), ('ADVANCES IN MATERIALS SCIENCE AND ENGINEERING', 1), ('EARTHQUAKE ENGINEERING & STRUCTURAL DYNAMICS', 1), ('EXPERT SYSTEMS', 1), ('ENVIRONMENTAL EARTH SCIENCES', 1), ('JOURNAL OF TRAFFIC AND TRANSPORTATION ENGINEERING-ENGLISH EDITION', 1), ('SAFETY SCIENCE', 1), ('JOURNAL OF CONSTRUCTIONAL STEEL RESEARCH', 1), ('MATERIALS AND STRUCTURES', 1), ('TUNNELLING AND UNDERGROUND SPACE TECHNOLOGY', 1), ('EUROPEAN JOURNAL OF ENVIRONMENTAL AND CIVIL ENGINEERING', 1), ('INTERNATIONAL JOURNAL OF GEOTECHNICAL ENGINEERING', 1), ('MECHANICS OF ADVANCED MATERIALS AND STRUCTURES', 1), ('BULLETIN OF EARTHQUAKE ENGINEERING', 1), ('INTERNATIONAL JOURNAL FOR NUMERICAL AND ANALYTICAL METHODS IN GEOMECHANICS', 1), ('RELIABILITY ENGINEERING & SYSTEM SAFETY', 1), ('ENERGY', 1), ('MRS COMMUNICATIONS', 1), ('GEOSCIENCES', 1), ('EUROPEAN JOURNAL OF INTEGRATIVE MEDICINE', 1), ('SOIL DYNAMICS AND EARTHQUAKE ENGINEERING', 1), ('JOURNAL OF TRANSPORTATION ENGINEERING PART B-PAVEMENTS', 1), ('COMPOSITE STRUCTURES', 1), ('BIOTECHNOLOGY AND APPLIED BIOCHEMISTRY', 1), ('CEMENT & CONCRETE COMPOSITES', 1), ('MECHANICAL SYSTEMS AND SIGNAL PROCESSING', 1), ('JOURNAL OF EARTHQUAKE ENGINEERING', 1), ('TRANSPORTATION RESEARCH RECORD', 1), ('BUILDINGS', 1), ('WATER', 1), ('CEMENT WAPNO BETON', 1), ('UNDERGROUND SPACE', 1), ('JOURNAL OF BUILDING ENGINEERING', 1), ('NUCLEAR ENGINEERING AND DESIGN', 1), ('JOURNAL OF VIBROENGINEERING', 1), ('BUILDING SIMULATION', 1), ('EARTHQUAKE SPECTRA', 1), ('MAGAZINE OF CIVIL ENGINEERING', 1), ('STRUCTURAL SAFETY', 1), ('INNOVATIONS IN INFRASTRUCTURE', 1), ('JOURNAL OF INTELLIGENT & FUZZY SYSTEMS', 1), ('ADVANCES IN CIVIL ENGINEERING', 1), ('JOURNAL OF APPLIED WATER ENGINEERING AND RESEARCH', 1), ('3RD WORLD MULTIDISCIPLINARY CIVIL ENGINEERING, ARCHITECTURE, URBAN PLANNING SYMPOSIUM (WMCAUS 2018)', 1), ('CURVED AND LAYERED STRUCTURES', 1), ('JOURNAL OF SUSTAINABLE CEMENT-BASED MATERIALS', 1), ('ZKG INTERNATIONAL', 1), ('IEEE ACCESS', 1), ('OPTIK', 1), ('THIN-WALLED STRUCTURES', 1), ('Advances in Intelligent Systems and Computing', 1), ('IOP Conference Series-Materials Science and Engineering', 1)]

# %%
# 统计机构
SumOrganizations={}
for str in data['C1']:
    Organizations={}
    if str.count('[')==1:
        c1=str.split(']')[-1].split(',')[0].strip()
        SumOrganizations[c1]=SumOrganizations.get(c1, 0) + 1
    else:
        for i in str.split('; ['):
            c1=i.split(']')[-1].split(',')[0].strip()
            Organizations[c1]=Organizations.get(c1, 0) + 1
        for key in Organizations.keys():
            SumOrganizations[key]=SumOrganizations.get(key, 0) + 1
print('共有机构：', len(SumOrganizations))
print(sorted(SumOrganizations.items(), key=lambda item:item[1], reverse=1))
# Out:
# Washington State Univ
# Duhok Polytech Univ
# Nawroz Univ
# Gaziantep Univ
# Istanbul Gelisim Univ
# Changan Univ
# Bursa Tech Univ
# Univ Burgos
# Univ Castilla La Mancha
# Univ Politecn Madrid
# Rhein Westfal TH Aachen
# Southeast Univ
# Tech Univ Dresden
# Harbin Inst Technol
# UET
# MNSUET
# Univ Aberdeen
# Univ Malaya
# Forsch Gemeinschaft Werkzeage & Werkstoffe eV
# RUB Ind Prod Serv Syst
# BUW Safety & Secur Syst
# Rhein Westfal TH Aachen
# Tsinghua Univ
# Harbin Inst Technol
# Tech Univ Dresden
# Univ Brasilia
# Xian Univ Architecture & Technol
# Xian Polytech Univ
# Univ TAHRI Mohammed
# Univ Innsbruck
# Univ Minho
# Dalian Univ Technol
# New York Inst Technol
# Univ Macau
# Zhuhai UM Sci & Technol Res Inst
# Chinese Acad Sci
# Univ Chinese Acad Sci
# Shantou Univ
# Natl Inst Technol
# Texas A&M Univ
# Univ Thessaly
# DAV Univ
# Lorestan Univ
# Indian Inst Technol
# Changan Univ
# Sichuan Univ
# Univ Ghent
# Univ Utrecht
# Shenyang Jianzhu Univ
# Liaoning Tech Univ
# Chongqing Univ
# Colorado Sch Mines
# Chongqing Triloop Detect Co
# Yangtze Normal Univ
# Chukwuemeka Odumegwu Ojukwu Univ
# Changan Univ
# Minist Transport
# Univ Baghdad
# Duy Tan Univ
# Baoji Univ Arts & Sci
# Deakin Univ
# Ton Duc Thang Univ
# Shandong Univ Sci & Technol
# Natl Univ Sci & Technol
# Seoul Natl Univ
# Guangzhou Univ
# Univ Burgos
# Univ Basque Country UPV EHU
# Spanish Inst Cement & Its Applicat IECA
# Univ Calabria
# Semnan Univ
# Univ Tokyo
# Changan Univ
# Zhaotong Municipal Peoples Govt Off
# Inha Univ
# Civil & Environm BG
# Korea Inst Civil Engn & Bldg Technol
# SN Construct Co Ltd
# Sirjan Univ Technol
# Yazd Univ
# Sharif Univ Technol
# Amirkabir Univ Technol
# Univ Guilan
# Univ Technol Sydney
# Natl Inst Technol
# NIT Kurukshetra
# Univ Art
# Queensland Univ Technol
# Univ Tabriz
# Univ Wollongong
# Univ Auckland
# Texas A&M Univ
# Zhejiang Univ
# Tongji Univ
# Colorado Sch Mines
# Shandong Univ Sci & Technol
# Indian Inst Technol
# Banaras Hindu Univ
# Indian Inst Technol Kanpur
# UTS
# Sch Pedag & Technol Educ
# Marquette Univ
# Islamic Azad Univ
# Univ Palermo
# Shenyang Jianzhu Univ
# Liaoning Tech Univ
# Birjand Univ Technol
# Imperial Coll London
# Univ Greenwich
# Korea Adv Inst Sci & Technol
# EDF Lab Chatou
# Univ Sao Paulo
# Estacio Univ Ctr Ribeirao Preto
# Tongji Univ
# Hohai Univ
# Univ Minho
# Fed Inst Goiano
# Univ Calif Berkeley
# Univ Patras
# Univ Brunei Darussalam
# Univ Cyprus
# Northwestern Polytech Univ
# Xi An Jiao Tong Univ
# Beijing Univ Technol
# Hangzhou Normal Univ
# Univ Baghdad
# Univ Miami
# Tongi Univ
# Ningbo Univ
# Tongji Univ
# Univ Norte
# Lorestan Univ
# No Arizona Univ
# Johns Hopkins Univ
# Vellore Inst Technol
# Natl Inst Technol
# Vietnam Natl Univ Agr
# Univ Transport Technol
# Nguyen Tat Thanh Univ
# Duy Tan Univ
# Southwest Petr Univ
# Chinese Acad Sci
# China Inst Water Resources & Hydropower Res
# Univ Tehran
# Pasteur Inst Iran
# Delft Univ Technol
# Univ New South Wales
# Univ Melbourne
# Beihang Univ
# Univ Nevada
# Abu Dhabi Univ
# Tennessee Dept Transportat
# Univ Tennessee
# Abu Dhabi Univ
# Cent Lille
# Univ Warmia & Mazury
# Univ Strathclyde
# Univ Toronto
# Harbin Inst Technol
# Isfahan Univ Technol
# Univ Sci & Technol Beijing
# USTB
# Virginia Tech
# Ayandegan Inst Higher Educ
# Babol Noshirvani Univ Technol
# Minist Hlth
# King Saud Univ
# Univ Babylon
# Arak Univ
# Iowa State Univ
# Univ Nevada
# Islamic Azad Univ
# Rhein Westfal TH Aachen
# Univ Sci & Technol Beijing
# Harbin Inst Technol
# Univ Paris Saclay
# IRSN
# United Arab Emirates Univ
# Univ Calgary
# China Univ Geosci
# Univ JJ Strossmayer
# Comp Sci & Informat Technol Osijek
# Univ Sarajevo
# Minist Educ
# Chongqing Univ
# Chongqing Construct Sci Res Inst
# Tongji Univ
# Jimei Univ
# Southwest Jiaotong Univ
# Univ Nevada
# Univ Nacl Autonoma Mexico
# Wroclaw Univ Sci & Technol
# Islamic Azad Univ
# Aligarh Muslim Univ
# Natl Res Moscow State Civil Engn Univ
# South China Univ Technol
# Univ Paris Saclay
# EDF Lab Paris Saclay
# French Alternat Energies & Atom Energy Commiss CE
# Pandit Deendayal Petr Univ
# SV Natl Inst Technol
# Univ Cent Ecuador
# Univ New Mexico
# Changsha Univ Sci & Technol
# Coinnovat Ctr Adv Construct & Maintenance Technol
# Natl Inst Technol
# Abu Dhabi Univ
# Swiss Fed Inst Technol
# Siam Res & Innovat Co
# Pathumthani Univ
# SCG Cement
# Univ Southern Calif
# Contour Crafting Corp
# Hong Kong Univ Sci & Technol
# Sony Comp Sci Labs Inc
# Wuhan Univ Technol
# China Railway 14th Construct Bur Grp Co Ltd
# Rutgers State Univ
# Gemini Technol Inc
# Univ Toronto
# Explora Secur Ltd
# Technion Israel Inst Technol
# 共有机构： 185
# [('Changan Univ', 4), ('Harbin Inst Technol', 4), ('Natl Inst Technol', 4), ('Tongji Univ', 4), ('Rhein Westfal TH Aachen', 3), ('Islamic Azad Univ', 3), ('Univ Nevada', 3), ('Abu Dhabi Univ', 3), ('Univ Burgos', 2), ('Tech Univ Dresden', 2), ('Univ Minho', 2), ('Chinese Acad Sci', 2), ('Texas A&M Univ', 2), ('Lorestan Univ', 2), ('Indian Inst Technol', 2), ('Shenyang Jianzhu Univ', 2), ('Liaoning Tech Univ', 2), ('Chongqing Univ', 2), ('Colorado Sch Mines', 2), ('Univ Baghdad', 2), ('Duy Tan Univ', 2), ('Shandong Univ Sci & Technol', 2), ('Univ Toronto', 2), ('Univ Sci & Technol Beijing', 2), ('Univ Paris Saclay', 2), ('Washington State Univ', 1), ('Duhok Polytech Univ', 1), ('Nawroz Univ', 1), ('Gaziantep Univ', 1), ('Istanbul Gelisim Univ', 1), ('Bursa Tech Univ', 1), ('Univ Castilla La Mancha', 1), ('Univ Politecn Madrid', 1), ('Southeast Univ', 1), ('UET', 1), ('MNSUET', 1), ('Univ Aberdeen', 1), ('Univ Malaya', 1), ('Forsch Gemeinschaft Werkzeage & Werkstoffe eV', 1), ('RUB Ind Prod Serv Syst', 1), ('BUW Safety & Secur Syst', 1), ('Tsinghua Univ', 1), ('Univ Brasilia', 1), ('Xian Univ Architecture & Technol', 1), ('Xian Polytech Univ', 1), ('Univ TAHRI Mohammed', 1), ('Univ Innsbruck', 1), ('Dalian Univ Technol', 1), ('New York Inst Technol', 1), ('Univ Macau', 1), ('Zhuhai UM Sci & Technol Res Inst', 1), ('Univ Chinese Acad Sci', 1), ('Shantou Univ', 1), ('Univ Thessaly', 1), ('DAV Univ', 1), ('Sichuan Univ', 1), ('Univ Ghent', 1), ('Univ Utrecht', 1), ('Chongqing Triloop Detect Co', 1), ('Yangtze Normal Univ', 1), ('Chukwuemeka Odumegwu Ojukwu Univ', 1), ('Minist Transport', 1), ('Baoji Univ Arts & Sci', 1), ('Deakin Univ', 1), ('Ton Duc Thang Univ', 1), ('Natl Univ Sci & Technol', 1), ('Seoul Natl Univ', 1), ('Guangzhou Univ', 1), ('Univ Basque Country UPV EHU', 1), ('Spanish Inst Cement & Its Applicat IECA', 1), ('Univ Calabria', 1), ('Semnan Univ', 1), ('Univ Tokyo', 1), ('Zhaotong Municipal Peoples Govt Off', 1), ('Inha Univ', 1), ('Civil & Environm BG', 1), ('Korea Inst Civil Engn & Bldg Technol', 1), ('SN Construct Co Ltd', 1), ('Sirjan Univ Technol', 1), ('Yazd Univ', 1), ('Sharif Univ Technol', 1), ('Amirkabir Univ Technol', 1), ('Univ Guilan', 1), ('Univ Technol Sydney', 1), ('NIT Kurukshetra', 1), ('Univ Art', 1), ('Queensland Univ Technol', 1), ('Univ Tabriz', 1), ('Univ Wollongong', 1), ('Univ Auckland', 1), ('Zhejiang Univ', 1), ('Banaras Hindu Univ', 1), ('Indian Inst Technol Kanpur', 1), ('UTS', 1), ('Sch Pedag & Technol Educ', 1), ('Marquette Univ', 1), ('Univ Palermo', 1), ('Birjand Univ Technol', 1), ('Imperial Coll London', 1), ('Univ Greenwich', 1), ('Korea Adv Inst Sci & Technol', 1), ('EDF Lab Chatou', 1), ('Univ Sao Paulo', 1), ('Estacio Univ Ctr Ribeirao Preto', 1), ('Hohai Univ', 1), ('Fed Inst Goiano', 1), ('Univ Calif Berkeley', 1), ('Univ Patras', 1), ('Univ Brunei Darussalam', 1), ('Univ Cyprus', 1), ('Northwestern Polytech Univ', 1), ('Xi An Jiao Tong Univ', 1), ('Beijing Univ Technol', 1), ('Hangzhou Normal Univ', 1), ('Univ Miami', 1), ('Tongi Univ', 1), ('Ningbo Univ', 1), ('Univ Norte', 1), ('No Arizona Univ', 1), ('Johns Hopkins Univ', 1), ('Vellore Inst Technol', 1), ('Vietnam Natl Univ Agr', 1), ('Univ Transport Technol', 1), ('Nguyen Tat Thanh Univ', 1), ('Southwest Petr Univ', 1), ('China Inst Water Resources & Hydropower Res', 1), ('Univ Tehran', 1), ('Pasteur Inst Iran', 1), ('Delft Univ Technol', 1), ('Univ New South Wales', 1), ('Univ Melbourne', 1), ('Beihang Univ', 1), ('Tennessee Dept Transportat', 1), ('Univ Tennessee', 1), ('Cent Lille', 1), ('Univ Warmia & Mazury', 1), ('Univ Strathclyde', 1), ('Isfahan Univ Technol', 1), ('USTB', 1), ('Virginia Tech', 1), ('Ayandegan Inst Higher Educ', 1), ('Babol Noshirvani Univ Technol', 1), ('Minist Hlth', 1), ('King Saud Univ', 1), ('Univ Babylon', 1), ('Arak Univ', 1), ('Iowa State Univ', 1), ('IRSN', 1), ('United Arab Emirates Univ', 1), ('Univ Calgary', 1), ('China Univ Geosci', 1), ('Univ JJ Strossmayer', 1), ('Comp Sci & Inform ...
# 32 0

# %%
z=data['C1'][1]
for i in z.split('; ['):
    
    c1=i.split(']')[-1].split(',')[0]
    print(c1)
# Out:
#  Duhok Polytech Univ
#  Nawroz Univ
#  Gaziantep Univ
#  Istanbul Gelisim Univ
